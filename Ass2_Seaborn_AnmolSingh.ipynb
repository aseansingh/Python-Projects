# %% [markdown]
# ### # Seaborn Exercises
#
# Time to practice your new `seaborn` skills! Try to recreate the plots below (don't worry about color schemes, just the plot itself.

# %% [markdown]
# ## The Data
#
# We will be working with a famous titanic data set for these exercises. Later on in the Machine Learning section of the course, we will revisit this data, and use it to predict survival rates of passengers. For now, we'll just focus on the visualization of the data with seaborn:

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.set_style('whitegrid')

# %%
df = sns.load_dataset('titanic')
df.shape
# Out:
# (891, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# # Exercises
#
# ** Recreate the plots below using the titanic dataframe. There are very few hints since most of the plots can be done with just one or two lines of code and a hint would basically give away the solution. Keep careful attention to the x and y labels for hints.**
#
# **Note! In order to not lose the plot image, make sure you don't code in the cell that is directly above the plot, there is an extra cell above that one which won't overwrite that plot!**

# %% [markdown]
# We want to check the missing values

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!

sns.heatmap(df.isnull(), yticklabels=False, cbar=False, cmap='viridis')
plt.show()

# %%
# Out:
# <AxesSubplot:>

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!

sns.histplot(data=df, x="fare", bins=30) 

plt.xlabel("fare", fontsize=8)
plt.ylabel("Frequency", fontsize=8)
plt.title("fare distribution with hist", fontsize=10)

plt.tight_layout()

plt.show()


sns.histplot(data=df, x="age", bins=30) 

plt.xlabel("age", fontsize=8)
plt.ylabel("Frequency", fontsize=8)
plt.title("fare distribution with hist", fontsize=10)

plt.tight_layout()

plt.show()

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!

plt.figure(figsize=(4.5, 3))

sns.set_style('whitegrid')

colors = ["steelblue", "darkorange"]

sns.countplot(x='survived', data=df,  palette=colors)
plt.xlabel("survived", fontsize = 8)
plt.ylabel("count", fontsize = 8)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)

plt.show()

# %%
# Countplot counts the each category of value and plot that.

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!

plt.figure(figsize=(4.2, 3))

colors = ["steelblue", "darkorange", "green"]

sns.countplot(x='pclass', data=df, palette=colors)
plt.xlabel("pclass", fontsize=8)
plt.ylabel("count", fontsize=8)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)

plt.show()

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!

plt.figure(figsize=(5, 6))

sns.jointplot(x="fare", y="age", data=df)

plt.xlim(-100, plt.xlim()[1])
plt.xlim(plt.xlim()[0], 600)

plt.ylim(-10, plt.ylim()[1])
plt.ylim(plt.ylim()[0], 80)

plt.yticks(range(0, 81, 20))
plt.show()

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!

plt.figure(figsize=(10, 6))

sns.histplot(data=df, x='fare', bins=30, color='red')

plt.ylabel('')
plt.xlabel('fare')

plt.ylim(0, 500)
plt.xlim(0, 600)

plt.show()

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!

colors = ["dodgerblue", "lightgreen", "darkorange"]
sns.boxplot(x='class', y='age', data=df, palette=colors)

plt.ylim(0, 80)

plt.show()

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!

plt.figure(figsize=(7, 6))
colors = ["lightgreen", "darkorange", "steelblue"]
sns.swarmplot(x='class', y='age', data=df, palette=colors, size=4, hue='class')
plt.legend(title='Class', loc='center left', bbox_to_anchor=(1, 0.5))
plt.yticks(range(0, 81, 20))
plt.show()

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!

plt.figure(figsize=(5, 4))
colors = ["steelblue", "lightgreen"]
sns.countplot(x='sex', data=df, palette=colors)
plt.xlabel("sex", fontsize=10)
plt.ylabel("count", fontsize=10)
plt.ylim(0, 600)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.show()

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!

selected_columns = ['adult_male', 'alone']
numeric_df = df.select_dtypes(include=['float64', 'int64'])
numeric_df[selected_columns] = df[selected_columns].astype(int)
numeric_df.fillna(numeric_df.mean(), inplace=True)

plt.figure(figsize=(5, 3))
co = numeric_df.corr()
plt.title("titanic.corr()")
labels = list(numeric_df.columns)
heatmap = sns.heatmap(co, center=0, annot=False, cmap='coolwarm', vmin=-0.8, vmax=0.8, xticklabels=labels, yticklabels=labels)
plt.xticks(rotation=45)
plt.yticks(rotation=0)

cbar = heatmap.collections[0].colorbar
cbar.set_ticks([-0.8, -0.4, 0.0, 0.4, 0.8])
cbar.set_ticklabels(['-0.8', '-0.4', '0.0', '0.4', '0.8'])

plt.show()

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!
import warnings
warnings.filterwarnings("ignore")

df = df.dropna(subset=['age', 'sex'])
g = sns.FacetGrid(df, col="sex", height=4, aspect=1)
g.map(plt.hist, "age", bins=10, color="steelblue")
plt.ylim(0, 120)
plt.xlim(0, 80)
plt.show()
